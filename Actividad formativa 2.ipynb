# %%
library(readr)
library(readxl)

# %%
data <- read_excel('/home/taz/Documentos/git/Macro/Inflacion y desempleo.xlsx')

# %%
data #Inflación suecia 2008 y 2011. #Desempleo suecia 2010 #Desempleo 2005 #Desempleo 1999 # IPC 2001

#Años candidatos 1993 y el 2011
# Out:
#    Año  Inflacion_suecia desempleo_suecia PIB          C
# 1    NA          NA          NA                     NA           NA
# 2  1991  9.44462733       3.243           271983749285 133331930550
# 3  1992  2.37436725       5.722           281993200316 139500052388
# 4  1993  4.72817305       9.330           211209754092 106825808773
# 5  1994  2.15813801       9.580           227272161742 112750129601
# 6  1995  2.45514858       8.897           265392735480 126844658153
# 7  1996  0.53313198       9.547           289755592007 138510438413
# 8  1997  0.65841026      10.359           266383711640 127183591141
# 9  1998 -0.26713267       8.941           268916086995 126847759091
# 10 1999  0.46217576       7.607           272292917312 128792481603
# 11 2000  0.89914373       5.466           261337451704 123552858484
# 12 2001  2.40595834       4.730           241018965834 112800340785
# 13 2002  2.15848214       4.965           265336496493 124347392961
# ...

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$Inflacion_suecia),type="p",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)

matplot(data$Año, cbind(data$desempleo_suecia),type="p",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='desempleo',main='Desempleo en Suecia',las=1)

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Balanza comercial suecia')

matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto en suecia')
       
matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo en suecia')

matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB en suecia')

matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Inversión en suecia')
# Out:
# Plot with title “Balanza comercial suecia”
# Plot with title “Gasto en suecia”
# Plot with title “Consumo en suecia”
# Plot with title “PIB en suecia”
# Plot with title “Inversión en suecia”

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='% desempleo',main='Desempleo en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Balanza comercial suecia')

matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='% desempleo',main='Desempleo en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto en suecia')
       
matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='% desempleo',main='Desempleo en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo en suecia')

matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='% desempleo',main='Desempleo en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB en suecia')

matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='% desempleo',main='Desempleo en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Inversión en suecia')
# Out:
# Plot with title “Balanza comercial suecia”
# Plot with title “Gasto en suecia”
# Plot with title “Consumo en suecia”
# Plot with title “PIB en suecia”
# Plot with title “Inversión en suecia”

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en Suecia',las=1)
abline(h=0)
matplot(data$Año, cbind(data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='desempleo',main='Desempleo en Suecia',las=1)
# Out:
# Plot with title “Desempleo en Suecia”

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='C/PIB',main='Porcentaje del consumo en el PIB',las=1)
matplot(data$Año, cbind(data$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Inflacion", "Consumo"), fill = c("red", "green"))
abline(h=0)
# Out:
# Plot with title “Variación del PIB vs Año”
