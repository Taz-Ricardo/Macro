# %%
library(readr)
library(readxl)

# %%
data <- read_excel('/home/taz/Documentos/git/Macro/Inflacion y desempleo.xlsx')

# %%
data
# Out:
#    Año  Inflacion_chile Inflacion_suecia desempleo_chile desempleo_suecia
# 1    NA        NA                NA          NA             NA
# 2  1999 3.3368792        0.46217576      11.158          7.607
# 3  2000 3.8432730        0.89914373      10.491          5.466
# 4  2001 3.5691005        2.40595834      10.390          4.730
# 5  2002 2.4893982        2.15848214      10.168          4.965
# 6  2003 2.8101788        1.92565535       9.765          5.555
# 7  2004 1.0547387        0.37365983      10.162          6.693
# 8  2005 3.0525762        0.45317085       9.340          7.486
# 9  2006 3.3920173        1.36021469       9.024          7.066
# 10 2007 4.4077994        2.21216883       8.427          6.161
# 11 2008 8.7162687        3.43704911       9.285          6.235
# 12 2009 0.3530452       -0.49446054      11.313          8.351
# 13 2010 1.4107111        1.15798803       8.424          8.610
# 14 2011 3.3412169        2.96115074       7.344          7.804
# ...

# %%
par(mfrow=c(2,1))
matplot(data$Año, cbind(data$Inflacion_chile,data$Inflacion_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Inflación en los paises',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)
matplot(data$Año, cbind(data$desempleo_chile,data$desempleo_suecia),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='IPC',main='Desempleo',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Desempleo”

# %%
# Out:
# Plot with title “Desempleo”
