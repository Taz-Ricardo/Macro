# %%
library(readr)
library(readxl)

# %%
chile <- read_excel('/home/taz/Documentos/git/Mat-266/modelo_neoclasico_pib.xlsx', sheet='Chile')
suecia <- read_excel('/home/taz/Documentos/git/Mat-266/modelo_neoclasico_pib.xlsx', sheet='Suecia')

# %%
chile
# Out:
#    AÑO  PIB          C            I           G           XN
# 1  1960   4110000000   3230180539   578558174   425936694  -114140072
# 2  1961   4609727273   3615811958   715134719   485892772  -189928350
# 3  1962   5416272727   4219152813   689668710   601914577   -78359210
# 4  1963   5668187500   4422561547   867477342   545534395  -140089031
# 5  1964   5982347826   4619119746   875381859   570897321   -58487649
# 6  1965   6026593750   4431270770   931692722   645858534    37575946
# 7  1966   7072641026   5041813431  1190836061   794191920    66175547
# 8  1967   7013196078   5004434548  1167241394   784062333    80037078
# 9  1968   7167086957   5144333985  1214958401   794793690    43039607
# 10 1969   8377093023   5982695857  1315523121   931602202   168866513
# 11 1970   9126309735   6398533769  1563180643  1167298200    35272854
# 12 1971  10884114754   7756685723  1657856187  1661259169  -131107015
# 13 1972  11853817308   8919265668  1518250060  1906237753  -426955821
# ...

# %%
suecia
# Out:
#    AÑO  PIB          C            I            G            XN
# 1  1960  15822585034   8833664055   5378185232   2385265214  -101121293
# 2  1961  17212686615   9514398648   5758982425   2589324158    61816337
# 3  1962  18667251380  10219648328   6196004687   2968042061    44034612
# 4  1963  20204870630  10991186771   6684907386   3314265286    31135754
# 5  1964  22532416750  11839212248   8013352879   3675381895    33804755
# 6  1965  24795499686  13014562994   9000614320   4175761490  -215543071
# 7  1966  26971486546  14137549542   9376044555   4833198769  -189333658
# 8  1967  29275995675  15241512408   9854724510   5421584822   -34550017
# 9  1968  31066819929  16147001219  10130994149   6057165537   -77309792
# 10 1969  33738102482  17432963980  11099599069   6644197654  -141510432
# 11 1970  37780565240  18944110357  12873270278   7708800800  -226491978
# 12 1971  41226082639  20597660333  12741096939   8816283540   401935933
# ...

# %%
par(mfrow=c(3,2))

plot(chile$PIB,suecia$PIB,xlab='PIB de Chile',ylab='PIB de Suecia' , main='PIB vs PIB',las=1)

plot(chile$C,suecia$C,xlab='Consumo de Chile',ylab='Consumo de Suecia' , main='Consumo vs consumo',las=1)

plot(chile$I,suecia$I,xlab='Inversión de Chile',ylab='Inversión de Suecia' , main='Inversión vs Inversión',las=1)

plot(chile$G,suecia$G,xlab='Gasto publico de Chile',ylab='Gasto publico de Suecia' , main='Gasto publico vs Gasto publico',las=1)

plot(chile$XN,suecia$XN,xlab='Balanza comercial de Chile',ylab='Balancza de Suecia' , main='Balanza comercial vs balanza comercial',las=1)
# Out:
# Plot with title “Balanza comercial vs balanza comercial”

# %%
# Out:
# Warning message in as.data.frame.numeric(suecia$AÑO, suecia$Variacion_p_PIB):
# “'row.names' is not a character vector of length 59 -- omitting it. Will be an error!”
#    suecia$AÑO
# 1  1960
# 2  1961
# 3  1962
# 4  1963
# 5  1964
# 6  1965
# 7  1966
# 8  1967
# 9  1968
# 10 1969
# 11 1970
# 12 1971
# 13 1972
# 14 1973
# 15 1974
# 16 1975
# 17 1976
# 18 1977
# 19 1978
# 20 1979
# 21 1980
# 22 1981
# 23 1982
# 24 1983
# 25 1984
# 26 1985
# 27 1986
# 28 1987
# 29 1988
# 30 1989
# 31 1990
# 32 1991
# 33 1992
# 34 1993
# 35 1994
# 36 1995
# 37 1996
# 38 1997
# 39 1998
# 40 1999
# 41 2000
# 42 2001
# 43 2002
# 44 2003
# 45 2004
# 46 2005
# 47 2006
# 48 2007
# 49 2008
# 50 2009
# 51 2010
# 52 2011
# 53 2012
# 54 2013
# 55 2014
# 56 2015
# 57 2016
# 58 2017
# 59 2018

# %%
par(mfrow=c(2,1))

matplot(chile$AÑO, cbind(chile$p_C_PIB,suecia$p_C_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='C/PIB',main='Porcentaje del consumo en el PIB',las=1)
matplot(chile$AÑO, cbind(chile$Variacion_p_PIB,suecia$Variacion_p_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)

matplot(chile$AÑO, cbind(chile$p_I_PIB,suecia$p_I_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='I/PIB',main='Porcentaje de Inversión en el PIB',las=1)
matplot(chile$AÑO, cbind(chile$Variacion_p_PIB,suecia$Variacion_p_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)

matplot(chile$AÑO, cbind(chile$p_G_PIB,suecia$p_G_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='G/PIB',main='Porcentaje del gasto en el PIB',las=1)
matplot(chile$AÑO, cbind(chile$Variacion_p_PIB,suecia$Variacion_p_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)

matplot(chile$AÑO, cbind(chile$p_XN_PIB,suecia$p_XN_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='XN/PIB',main='Porcentaje de la Balanza comercial en el PIB',las=1)
matplot(chile$AÑO, cbind(chile$Variacion_p_PIB,suecia$Variacion_p_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)
# Out:
# Plot with title “Variación del PIB vs Año”
# Plot with title “Variación del PIB vs Año”
# Plot with title “Variación del PIB vs Año”
# Plot with title “Variación del PIB vs Año”

# %%
par(mfrow=c(2,2))

matplot(chile$AÑO, cbind(chile$p_C_PIB,suecia$p_C_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='C/PIB',main='Consumo/PIB',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$p_I_PIB,suecia$p_I_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='I/PIB',main='Ingreso/PIB',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$p_G_PIB,suecia$p_G_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='G/PIB',main='Gasto dividida en PIB',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$p_XN_PIB,suecia$p_XN_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='XN/PIB',main='Balanza comercial divida en PIB',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))


matplot(chile$AÑO, cbind(chile$PIB,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='PIB en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Consumo',main='Consumo en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Ingreso',main='Ingreso en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Gasto en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Balanza comercial en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$p_error,suecia$p_error),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Porcentaje de error del PIB',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y consumo de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y consumo de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile e Ingreso de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia e Ingreso de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y Gastos de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile e Inversión de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia e Inversión de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile y Gastos de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingreso de Chile y Gastos de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingresos de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingreso de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingresos de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$EXP_PIB,suecia$EXP_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Exportaciones nacionales dividido en pib vs Año',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$IMP_PIB,suecia$IMP_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Importaciones nacionales dividido en pib vs Año',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Balanza comercial divida en PIB”
# Plot with title “Gasto en US$”
# Plot with title “PIB de Suecia y consumo de Chile en US$”
# Plot with title “PIB de Suecia y Gastos de Chile en US$”
# Plot with title “Consumo de Suecia e Inversión de Chile en US$”
# Plot with title “Consumo de Suecia y Balanza Comercial de Chile en US$”
# Plot with title “Ingresos de Suecia y Balanza Comercial de Chile en US$”
# Plot with title “Importaciones nacionales dividido en pib vs Año”

# %%
par(mfrow=c(2,1))

matplot(chile$AÑO, cbind(chile$PIB,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='PIB en US$')
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$Variacion_p_PIB,suecia$Variacion_p_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Variación del PIB vs Año',las=1)
legend(x = 'bottomleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
abline(h=0)
# Out:
# Plot with title “Variación del PIB vs Año”

# %%
matplot(chile$AÑO, cbind(chile$p_error,suecia$p_error),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Porcentaje de error del PIB',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$'PIB-C-I-G-XN',suecia$'PIB-C-I-G-XN'),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='Error en el PIB')
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))
mtext("(1)", side=1, line=4, font=1)
# Out:
# Plot with title “Porcentaje de error del PIB”
# Plot with title “Error en el PIB”

# %%
matplot(chile$AÑO, cbind(chile$PIB,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='PIB',main='PIB en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “PIB en US$”

# %%
matplot(chile$AÑO, cbind(chile$C,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Consumo',main='Consumo en US$')
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Consumo en US$”

# %%
matplot(chile$AÑO, cbind(chile$I,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Ingreso',main='Ingreso en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Gasto en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Balanza comercial en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$p_error,suecia$p_error),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Porcentaje de error del PIB',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y consumo de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y consumo de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile e Ingreso de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia e Ingreso de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y Gastos de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='PIB de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

# %%
matplot(chile$AÑO, cbind(chile$C,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile e Inversión de Suecia en US$')
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Consumo de Chile e Inversión de Suecia en US$”

# %%
matplot(chile$AÑO, cbind(chile$I,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia e Inversión de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

# %%
matplot(chile$AÑO, cbind(chile$C,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile y Gastos de Suecia en US$')
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Consumo de Chile y Gastos de Suecia en US$”

# %%
matplot(chile$AÑO, cbind(chile$G,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$C,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Consumo de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingreso de Chile y Gastos de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingresos de Suecia y Gastos de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$I,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingreso de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$I),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Ingresos de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$G,suecia$XN),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto de Chile y Balanza Comercial de Suecia en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$XN,suecia$G),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Gasto de Suecia y Balanza Comercial de Chile en US$',las=1)
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$EXP_PIB,suecia$EXP_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Exportaciones nacionales dividido en pib vs Año',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$IMP_PIB,suecia$IMP_PIB),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='Importaciones nacionales dividido en pib vs Año',las=1)
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Ingreso en US$”
# Plot with title “Gasto en US$”
# Plot with title “Balanza comercial en US$”
# Plot with title “Porcentaje de error del PIB”
# Plot with title “PIB de Chile y consumo de Suecia en US$”
# Plot with title “PIB de Suecia y consumo de Chile en US$”
# Plot with title “PIB de Chile e Ingreso de Suecia en US$”
# Plot with title “PIB de Suecia e Ingreso de Chile en US$”
# Plot with title “PIB de Chile y Gastos de Suecia en US$”
# Plot with title “PIB de Suecia y Gastos de Chile en US$”
# Plot with title “PIB de Chile y Balanza Comercial de Suecia en US$”
# Plot with title “PIB de Suecia y Balanza Comercial de Chile en US$”
# Plot with title “Consumo de Chile e Inversión de Suecia en US$”
# Plot with title “Consumo de Suecia e Inversión de Chile en US$”
# Plot with title “Consumo de Chile y Gastos de Suecia en US$”
# Plot with title “Consumo de Suecia y Gastos de Chile en US$”
# Plot with title “Consumo de Chile y Balanza Comercial de Suecia en US$”
# ...

# %%
matplot(chile$AÑO, cbind(chile$EXP,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='US$',main='Exportaciones chile vs consumo suecia')
legend(x = 'topleft', legend = c("Chile", "Suecia"), fill = c("red", "green"))

matplot(chile$AÑO, cbind(chile$PIB,suecia$C),type="l",col=c("red","green"),lty=c(1,1),xlab='Años',ylab='Gasto',main='PIB de chile vs consumo suecia')
legend(x = 'bottomright', legend = c("Chile", "Suecia"), fill = c("red", "green"))
# Out:
# Plot with title “Exportaciones chile vs consumo suecia”
# Plot with title “PIB de chile vs consumo suecia”
